# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus']=False
plt.rc('font',family = 'Malgun Gothic')

# %%
df=pd.read_csv('./data1/서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv',encoding='cp949', low_memory=False)

# %%
df
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0      202108  1호선  동대문           415            11         10380
# 1      202108  1호선  동묘앞            84             3          2861
# 2      202108  1호선  서울역           483            11          7963
# 3      202108  1호선   시청             6             0          1597
# 4      202108  1호선  신설동           247             6          6828
# ...       ...  ...  ...           ...           ...           ...
# 46547  201501  중앙선  운길산             0             0           177
# 46548  201501  중앙선   원덕             1             0           292
# 46549  201501  중앙선   중랑            14             1          4929
# 46550  201501  중앙선   팔당             0             0           161
# 46551  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0              1815          7880          5352         12037  ...
# ...

# %%
df.shape
# Out:
# (46552, 52)

# %%
df.isnull().sum()
# Out:
# 사용월             0
# 호선명             0
# 지하철역            0
# 04시-05시 승차인원    0
# 04시-05시 하차인원    0
# 05시-06시 승차인원    0
# 05시-06시 하차인원    0
# 06시-07시 승차인원    0
# 06시-07시 하차인원    0
# 07시-08시 승차인원    0
# 07시-08시 하차인원    0
# 08시-09시 승차인원    0
# 08시-09시 하차인원    0
# 09시-10시 승차인원    0
# 09시-10시 하차인원    0
# 10시-11시 승차인원    0
# 10시-11시 하차인원    0
# 11시-12시 승차인원    0
# 11시-12시 하차인원    0
# 12시-13시 승차인원    0
# 12시-13시 하차인원    0
# 13시-14시 승차인원    0
# 13시-14시 하차인원    0
# 14시-15시 승차인원    0
# 14시-15시 하차인원    0
# 15시-16시 승차인원    0
# 15시-16시 하차인원    0
# 16시-17시 승차인원    0
# 16시-17시 하차인원    0
# 17시-18시 승차인원    0
# 17시-18시 하차인원    0
# 18시-19시 승차인원    0
# 18시-19시 하차인원    0
# 19시-20시 승차인원    0
# 19시-20시 하차인원    0
# 20시-21시 승차인원    0
# 20시-21시 하차인원    0
# 21시-22시 승차인원    0
# 21시-22시 하차인원    0
# 22시-23시 승차인원    0
# 22시-23시 하차인원    0
# 23시-24시 승차인원    0
# 23시-24시 하차인원    0
# 00시-01시 승차인원    0
# 00시-01시 하차인원    0
# 01시-02시 승차인원    0
# 01시-02시 하차인원    0
# 02시-03시 승차인원    0
# 02시-03시 하차인원    0
# 03시-04시 승차인원    0
# ...

# %%
#컬럼별 데이터 확인

# %%
df['사용월'].unique()
# Out:
# array([202108, 202107, 202106, 202105, 202104, 202103, 202102, 202101,
#        202012, 202011, 202010, 202009, 202008, 202007, 202006, 202005,
#        202004, 202003, 202002, 202001, 201912, 201911, 201910, 201909,
#        201908, 201907, 201906, 201905, 201904, 201903, 201902, 201901,
#        201812, 201811, 201810, 201809, 201808, 201807, 201806, 201805,
#        201804, 201803, 201802, 201801, 201712, 201711, 201710, 201709,
#        201708, 201707, 201706, 201705, 201704, 201703, 201702, 201701,
#        201612, 201611, 201610, 201609, 201608, 201607, 201606, 201605,
#        201604, 201603, 201602, 201601, 201512, 201511, 201510, 201509,
#        201508, 201507, 201506, 201505, 201504, 201503, 201502, 201501],
#       dtype=int64)

# %%
df['사용월'].nunique()
# Out:
# 80

# %%
df['호선명'].unique()
# Out:
# array(['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '8호선', '9호선',
#        '9호선2~3단계', '경강선', '경부선', '경원선', '경의선', '경인선', '경춘선', '공항철도 1호선',
#        '과천선', '분당선', '수인선', '안산선', '우이신설선', '일산선', '장항선', '중앙선', '9호선2단계'],
#       dtype=object)

# %%
df['호선명'].nunique()
# Out:
# 26

# %%
df.dtypes
# Out:
# 사용월              int64
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %%
#사용월을 문자열로 형태 변경
df['사용월'] = df['사용월'].astype('str')
df.dtypes
# Out:
# 사용월             object
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %%
df.drop(columns=['작업일자'], inplace= True)

# %%
df.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
# 2  202108  1호선  서울역           483            11          7963          5533
# 3  202108  1호선   시청             6             0          1597          4399
# 4  202108  1호선  신설동           247             6          6828          2721
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 승차인원  23시-24시 하차인원  \
# 0          7880          5352         12037  ...          1633          5983
# 1          3286          4614          5128  ...           577          1759
# 2         10871         31479         31643  ...          7756          4968
# 3          2727         17957          5971  ...          2462           822
# 4          7333          9771         14821  ...          1352          3747
#
# ...

# %%
#공통 컬럼 df1 
#승차 컬럼 df2 
#하차 컬럼 df3

df1= df.iloc[:,:3]

# %%
df1
# Out:
#           사용월  호선명 지하철역
# 0      202108  1호선  동대문
# 1      202108  1호선  동묘앞
# 2      202108  1호선  서울역
# 3      202108  1호선   시청
# 4      202108  1호선  신설동
# ...       ...  ...  ...
# 46547  201501  중앙선  운길산
# 46548  201501  중앙선   원덕
# 46549  201501  중앙선   중랑
# 46550  201501  중앙선   팔당
# 46551  201501  중앙선   회기
#
# [46552 rows x 3 columns]

# %%
df2 = df.iloc[:,3::2]

# %%
df2
# Out:
#        04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 0               415         10380          7880         12037         16637
# 1                84          2861          3286          5128          8066
# 2               483          7963         10871         31643         49003
# 3                 6          1597          2727          5971          6884
# 4               247          6828          7333         14821         20523
# ...             ...           ...           ...           ...           ...
# 46547             0           177           642          1292          1479
# 46548             1           292           415           537           823
# 46549            14          4929          8539         22160         25792
# 46550             0           161           368          1227           910
# 46551           436         10929         23317         65043         85473
#
# ...

# %%
df3 = df.iloc[:,4::2]  # 컬럼명에 공통 단어로 뽑는 방법 ?

# %%
df3
# Out:
#        04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 0                11          1815          5352          9885         19783
# 1                 3           918          4614          8004         18779
# 2                11          5533         31479         73669        149249
# 3                 0          4399         17957         53669        141150
# 4                 6          2721          9771         21765         52910
# ...             ...           ...           ...           ...           ...
# 46547             0            56           403           675          1390
# 46548             0             4            46           248           344
# 46549             1           424          2084          3027          6573
# 46550             0            50           149           523          1151
# 46551             3          3067         10430         24473         59383
#
# ...

# %%
df2.columns = df2.columns.str.split(' ').str[0]
df2
# Out:
#        04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 0          415    10380     7880    12037    16637    15671    13922    15675
# 1           84     2861     3286     5128     8066     7541     9130    13369
# 2          483     7963    10871    31643    49003    36383    35273    41477
# 3            6     1597     2727     5971     6884     7541     8328    12240
# 4          247     6828     7333    14821    20523    14881    13551    15578
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 46547        0      177      642     1292     1479     1438     1408     1179
# 46548        1      292      415      537      823      980     1025      720
# 46549       14     4929     8539    22160    25792    14328    11117    10340
# 46550        0      161      368     1227      910      897     1009      904
# 46551      436    10929    23317    65043    85473    54247    42703    44815
#
# ...

# %%
#승차
df_in = pd.concat([df1,df2],axis=1)
df_in
# Out:
#           사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1      202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 2      202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 3      202108  1호선   시청        6     1597     2727     5971     6884     7541
# 4      202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ...       ...  ...  ...      ...      ...      ...      ...      ...      ...
# 46547  201501  중앙선  운길산        0      177      642     1292     1479     1438
# 46548  201501  중앙선   원덕        1      292      415      537      823      980
# 46549  201501  중앙선   중랑       14     4929     8539    22160    25792    14328
# 46550  201501  중앙선   팔당        0      161      368     1227      910      897
# 46551  201501  중앙선   회기      436    10929    23317    65043    85473    54247
#
# ...

# %%
df3.columns = df3.columns.str.split(' ').str[0]
df3
# Out:
#        04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 0           11     1815     5352     9885    19783    19192    17298    19346
# 1            3      918     4614     8004    18779    15213    17602    21823
# 2           11     5533    31479    73669   149249    94786    50691    42942
# 3            0     4399    17957    53669   141150    60972    24743    22388
# 4            6     2721     9771    21765    52910    28274    18729    16195
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 46547        0       56      403      675     1390     3270     3673     3090
# 46548        0        4       46      248      344      273      497      504
# 46549        1      424     2084     3027     6573     6133     5605     5192
# 46550        0       50      149      523     1151     2931     3932     2199
# 46551        3     3067    10430    24473    59383    41911    35003    33229
#
# ...

# %%
#하차
df_out = pd.concat([df1,df3],axis=1)
df_out
# Out:
#           사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      202108  1호선  동대문       11     1815     5352     9885    19783    19192
# 1      202108  1호선  동묘앞        3      918     4614     8004    18779    15213
# 2      202108  1호선  서울역       11     5533    31479    73669   149249    94786
# 3      202108  1호선   시청        0     4399    17957    53669   141150    60972
# 4      202108  1호선  신설동        6     2721     9771    21765    52910    28274
# ...       ...  ...  ...      ...      ...      ...      ...      ...      ...
# 46547  201501  중앙선  운길산        0       56      403      675     1390     3270
# 46548  201501  중앙선   원덕        0        4       46      248      344      273
# 46549  201501  중앙선   중랑        1      424     2084     3027     6573     6133
# 46550  201501  중앙선   팔당        0       50      149      523     1151     2931
# 46551  201501  중앙선   회기        3     3067    10430    24473    59383    41911
#
# ...

# %%
#최근월을 기준으로 승하차 데이터 프레임 형성 
df_in_2108 = df_in[df_in['사용월']=='202108']
df_out_2108 = df_out[df_out['사용월']=='202108']

# %%
#출근시간에 가장 많은 사람이 승차하는 역은 어디 일까?(08시-09시)
df_in_2108.nlargest(10,'08시-09시')[['지하철역','08시-09시']]
# Out:
#             지하철역  08시-09시
# 37            신림   267128
# 14       구로디지털단지   153411
# 28   서울대입구(관악구청)   150090
# 83           연신내   132615
# 133          까치산   130443
# 52      잠실(송파구청)   128005
# 175           화곡   121310
# 112           쌍문   112812
# 36           신도림   111452
# 35           신대방   110766

# %%
#출근시간에 가장 많은 사람이 하차하는 역은 어디 일까?(09시-10시)
df_out_2108.nlargest(10,'09시-10시')[['지하철역','09시-10시']]
# Out:
#            지하철역  09시-10시
# 10           강남   274355
# 43           역삼   226437
# 215     가산디지털단지   188412
# 30           선릉   178766
# 26     삼성(무역센터)   172539
# 80          압구정   139283
# 31           성수   124935
# 78           신사   122905
# 13   교대(법원.검찰청)   121163
# 14      구로디지털단지   121092

# %%
#퇴근시간에 가장 많은 사람이 승차하는 역은 어디 일까?(08시-09시)
df_in_2108.nlargest(10,'18시-19시')[['지하철역','18시-19시']]
# Out:
#             지하철역  18시-19시
# 10            강남   302398
# 215      가산디지털단지   283125
# 30            선릉   245318
# 43            역삼   239209
# 26      삼성(무역센터)   230299
# 50         을지로입구   207093
# 31            성수   202624
# 14       구로디지털단지   192537
# 82      양재(서초구청)   174296
# 128  광화문(세종문화회관)   173772

# %%
#퇴근시간에 가장 많은 사람이 하차하는 역은 어디 일까?(09시-10시)
df_out_2108.nlargest(10,'19시-20시')[['지하철역','19시-20시']]
# Out:
#             지하철역  19시-20시
# 37            신림   182832
# 28   서울대입구(관악구청)   121426
# 52      잠실(송파구청)   116568
# 14       구로디지털단지   107520
# 83           연신내   103283
# 36           신도림    97759
# 109     수유(강북구청)    93666
# 133          까치산    87948
# 112           쌍문    86631
# 438           부천    85018

# %%
#강남역 최근 시간대별 승하차 정보 분석
#df_gangnam_in = df_in_2108.iloc[10]
#df_gangnam_in

# %%
#df_gangnam_out = df_out_2108.iloc[10]
#df_gangnam_out

# %%
df_gangnam_in = df_in_2108[df_in_2108['지하철역']=='강남'].iloc[:,3:]
df_gangnam_in
# Out:
#     04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 10       64     4993    14177    31783    50239    40611    44108    59573
#
#     12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 10    75942    88926  ...   302398   178242   138452   157847   105997
#
#     23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 10    12509        5        2        0        0
#
# [1 rows x 24 columns]

# %%
#melt : 일렬로 reshape
df_gangnam_in =df_gangnam_in.melt()
df_gangnam_in
# Out:
#    variable   value
# 0   04시-05시      64
# 1   05시-06시    4993
# 2   06시-07시   14177
# 3   07시-08시   31783
# 4   08시-09시   50239
# 5   09시-10시   40611
# 6   10시-11시   44108
# 7   11시-12시   59573
# 8   12시-13시   75942
# 9   13시-14시   88926
# 10  14시-15시   97964
# 11  15시-16시  120268
# 12  16시-17시  135621
# 13  17시-18시  214990
# 14  18시-19시  302398
# 15  19시-20시  178242
# 16  20시-21시  138452
# 17  21시-22시  157847
# 18  22시-23시  105997
# 19  23시-24시   12509
# 20  00시-01시       5
# 21  01시-02시       2
# 22  02시-03시       0
# 23  03시-04시       0

# %%
#컬럼명 변경
df_gangnam_in.columns=['시간대','승차건수']
df_gangnam_in.sort_values('승차건수',ascending=False)
# Out:
#         시간대    승차건수
# 14  18시-19시  302398
# 13  17시-18시  214990
# 15  19시-20시  178242
# 17  21시-22시  157847
# 16  20시-21시  138452
# 12  16시-17시  135621
# 11  15시-16시  120268
# 18  22시-23시  105997
# 10  14시-15시   97964
# 9   13시-14시   88926
# 8   12시-13시   75942
# 7   11시-12시   59573
# 4   08시-09시   50239
# 6   10시-11시   44108
# 5   09시-10시   40611
# 3   07시-08시   31783
# 2   06시-07시   14177
# 19  23시-24시   12509
# 1   05시-06시    4993
# 0   04시-05시      64
# 20  00시-01시       5
# 21  01시-02시       2
# 22  02시-03시       0
# 23  03시-04시       0

# %%
#시간대별 승차인원 시각화 하기 
plt.figure(figsize = (10,7))
plt.barh(df_gangnam_in['시간대'], df_gangnam_in['승차건수'])
plt.show()

# %%
df_gangnam_out = df_out_2108[df_in_2108['지하철역']=='강남'].iloc[:,3:]
df_gangnam_out
# Out:
#     04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 10        4    10411    45059   129595   269877   274355   129744    99120
#
#     12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 10    96644   115153  ...   125891    68747    34635    27783    21970
#
#     23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 10     8377       15        1        0        0
#
# [1 rows x 24 columns]

# %%
df_gangnam_out =df_gangnam_out.melt()
df_gangnam_out
# Out:
#    variable   value
# 0   04시-05시       4
# 1   05시-06시   10411
# 2   06시-07시   45059
# 3   07시-08시  129595
# 4   08시-09시  269877
# 5   09시-10시  274355
# 6   10시-11시  129744
# 7   11시-12시   99120
# 8   12시-13시   96644
# 9   13시-14시  115153
# 10  14시-15시   94620
# 11  15시-16시   86770
# 12  16시-17시   83690
# 13  17시-18시   96689
# 14  18시-19시  125891
# 15  19시-20시   68747
# 16  20시-21시   34635
# 17  21시-22시   27783
# 18  22시-23시   21970
# 19  23시-24시    8377
# 20  00시-01시      15
# 21  01시-02시       1
# 22  02시-03시       0
# 23  03시-04시       0

# %%
df_gangnam_out.columns=['시간대','하차건수']
df_gangnam_out.sort_values('하차건수',ascending=False)
# Out:
#         시간대    하차건수
# 5   09시-10시  274355
# 4   08시-09시  269877
# 6   10시-11시  129744
# 3   07시-08시  129595
# 14  18시-19시  125891
# 9   13시-14시  115153
# 7   11시-12시   99120
# 13  17시-18시   96689
# 8   12시-13시   96644
# 10  14시-15시   94620
# 11  15시-16시   86770
# 12  16시-17시   83690
# 15  19시-20시   68747
# 2   06시-07시   45059
# 16  20시-21시   34635
# 17  21시-22시   27783
# 18  22시-23시   21970
# 1   05시-06시   10411
# 19  23시-24시    8377
# 20  00시-01시      15
# 0   04시-05시       4
# 21  01시-02시       1
# 22  02시-03시       0
# 23  03시-04시       0

# %%
plt.figure(figsize = (10,7))
plt.barh(df_gangnam_out['시간대'], df_gangnam_out['하차건수'])  #(x축, y축)
plt.show()

# %%
#지하철 시간대별 역별 이용 현황 
#최근 202108데이터 중 승차정보 집계 데이터 만들기 
df_in_2108_agg =df_in_2108.copy()
df_out_2108_agg =df_out_2108.copy()

# %%
df_in_2108_agg
# Out:
#         사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0    202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1    202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 2    202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 3    202108  1호선   시청        6     1597     2727     5971     6884     7541
# 4    202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ..      ...  ...  ...      ...      ...      ...      ...      ...      ...
# 602  202108  중앙선   원덕       72      277      689      643      883      755
# 603  202108  중앙선   중랑      200     5961     8782    19739    18610    13213
# 604  202108  중앙선   지평        0        1        2      347      218       18
# 605  202108  중앙선   팔당        1      212      788     1261     1267     1123
# 606  202108  중앙선   회기      719    11133    18619    47471    59922    39563
#
# ...

# %%
#지하철 역 컬럼을 인덱스로 지정
df_in_2108_agg.index = df_in_2108_agg['지하철역']
df_in_2108_agg
# Out:
#          사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 지하철역
# 동대문   202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 동묘앞   202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 서울역   202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 시청    202108  1호선   시청        6     1597     2727     5971     6884     7541
# 신설동   202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ...      ...  ...  ...      ...      ...      ...      ...      ...      ...
# 원덕    202108  중앙선   원덕       72      277      689      643      883      755
# 중랑    202108  중앙선   중랑      200     5961     8782    19739    18610    13213
# 지평    202108  중앙선   지평        0        1        2      347      218       18
# 팔당    202108  중앙선   팔당        1      212      788     1261     1267     1123
# 회기    202108  중앙선   회기      719    11133    18619    47471    59922    39563
#
# ...

# %%
#불필요한 컬럼 지우기
df_in_2108_agg.drop(columns=['사용월','호선명','지하철역'], inplace=True)
df_in_2108_agg
# Out:
#       04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 지하철역
# 동대문       415    10380     7880    12037    16637    15671    13922    15675
# 동묘앞        84     2861     3286     5128     8066     7541     9130    13369
# 서울역       483     7963    10871    31643    49003    36383    35273    41477
# 시청          6     1597     2727     5971     6884     7541     8328    12240
# 신설동       247     6828     7333    14821    20523    14881    13551    15578
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 원덕         72      277      689      643      883      755      661      584
# 중랑        200     5961     8782    19739    18610    13213     8053     7475
# 지평          0        1        2      347      218       18      325        2
# 팔당          1      212      788     1261     1267     1123     1208     1127
# 회기        719    11133    18619    47471    59922    39563    31469    31674
#
# ...

# %%
##@@ margins 는 적용 불가?
df_in_2108_agg.loc['sum'] = df_in_2108_agg.apply('sum', axis=0)

# %%
df_in_2108_agg.tail()
# Out:
#       04시-05시  05시-06시  06시-07시   07시-08시   08시-09시  09시-10시  10시-11시  \
# 지하철역
# 중랑        200     5961     8782     19739     18610    13213     8053
# 지평          0        1        2       347       218       18      325
# 팔당          1      212      788      1261      1267     1123     1208
# 회기        719    11133    18619     47471     59922    39563    31469
# sum    125592  2679895  5392644  13007398  14639529  8962001  6688112
#
#       11시-12시  12시-13시  13시-14시  ...   18시-19시  19시-20시  20시-21시  21시-22시  \
# 지하철역                             ...
# 중랑       7475     7112     7262  ...      6531     4213     2938     2513
# 지평          2        4       65  ...        35      215        2       27
# 팔당       1127     1339     1521  ...      2857     2067     2057     1927
# 회기      31674    33153    30224  ...     38115    21128    17210    17437
# sum   6762631  7277223  7301932  ...  17191309  8671470  6611588  6032973
#
# ...

# %%
len(df_in_2108_agg)        # 전체 역은 608개
# Out:
# 608

# %%
#합계열 추가 
df_in_2108_agg['sum'] = df_in_2108_agg.apply('sum', axis=1)

# %%
df_in_2108_agg
# Out:
#       04시-05시  05시-06시  06시-07시   07시-08시   08시-09시  09시-10시  10시-11시  \
# 지하철역
# 동대문       415    10380     7880     12037     16637    15671    13922
# 동묘앞        84     2861     3286      5128      8066     7541     9130
# 서울역       483     7963    10871     31643     49003    36383    35273
# 시청          6     1597     2727      5971      6884     7541     8328
# 신설동       247     6828     7333     14821     20523    14881    13551
# ...       ...      ...      ...       ...       ...      ...      ...
# 중랑        200     5961     8782     19739     18610    13213     8053
# 지평          0        1        2       347       218       18      325
# 팔당          1      212      788      1261      1267     1123     1208
# 회기        719    11133    18619     47471     59922    39563    31469
# sum    125592  2679895  5392644  13007398  14639529  8962001  6688112
#
#       11시-12시  12시-13시  13시-14시  ...  19시-20시  20시-21시  21시-22시  22시-23시  \
# 지하철역                             ...
# ...

# %%
#시간대별 승차건수 
s_in = df_in_2108_agg.loc['sum'][:-1].sort_values()

# %%
x= s_in.index
y= s_in.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#역별 승차건수 
st_in = df_in_2108_agg['sum'][:-1].sort_values()

# %%
st_in
# Out:
# 지하철역
# 신내                3
# 검암                4
# 지축                4
# 계양                5
# 창동                6
#              ...
# 홍대입구        1247932
# 구로디지털단지     1331304
# 신림          1503604
# 잠실(송파구청)    1539356
# 강남          1874711
# Name: sum, Length: 607, dtype: int64

# %%
x= st_in.index
y= st_in.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#시간대별 하차 현황

# %%
df_out_2108_agg.index = df_out_2108_agg['지하철역']
df_out_2108_agg.drop(columns=['사용월','호선명','지하철역'], inplace=True)
df_out_2108_agg.loc['sum'] = df_out_2108_agg.apply('sum', axis=0)
df_out_2108_agg['sum'] = df_out_2108_agg.apply('sum', axis=1)
s_out = df_out_2108_agg.loc['sum'][:-1].sort_values()
print(df_out_2108_agg)
x= s_out.index
y= s_out.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show
# Out:
#       04시-05시  05시-06시  06시-07시  07시-08시   08시-09시   09시-10시  10시-11시  \
# 지하철역
# 동대문        11     1815     5352     9885     19783     19192    17298
# 동묘앞         3      918     4614     8004     18779     15213    17602
# 서울역        11     5533    31479    73669    149249     94786    50691
# 시청          0     4399    17957    53669    141150     60972    24743
# 신설동         6     2721     9771    21765     52910     28274    18729
# ...       ...      ...      ...      ...       ...       ...      ...
# 중랑          4      572     2261     2544      5744      4790     4282
# 지평          0        0        0      298        58         3      422
# 팔당          0      117      783     1603      2790      3084     3007
# 회기         12     3419    10520    24212     40739     26807    23533
# sum      1644   706189  3603606  8042590  17604264  11402630  7146549
#
#       11시-12시  12시-13시  13시-14시  ...   19시-20시  20시-21시  21시-22시  22시-23시  \
# 지하철역                             ...
# ...

# %%
#역별 하차건수

# %%
st_out = df_out_2108_agg['sum'][:-1].sort_values()
x= st_out.index
y= st_out.values
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
